# %% [markdown]
# # Topics Covered
# - Identifying and handling missing data.
# - Data transformation and normalization.
# - Data filtering and deduplication.
# - Standardization of categorical data.
# - Outlier detection and handling.

# %% [markdown]
# ## Exercise 1: Identifying and Handling Missing Data

# %%
# Melakukan import library pandas untuk memanipulasi data dan analisis data
import pandas as pd

# Menyiapkan dataset yang di isi dengan beberapa error kesalahan
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', None],
    'Age': [24, 30, None, 22, 35],
    'Salary': [48000, None, 57000, None, 60000]
}

# Menjadikan dataset sebagai dataframe pandas
df = pd.DataFrame(data)

# Melakukan pembersihan data

# Mengisi kolom kosong pada umur dimana kolom yang kosong di isi dengan rata - rata dari semua umur
df['Age'].fillna(df['Age'].mean(), inplace=True)

# Mengisi kolom kosong juga pada Gaji dimana kolom yang kosong di isi dengan nilai tengah dari gaji
df['Salary'].fillna(df['Salary'].median(), inplace=True)

# Menghapus data pada Name apabila terdapat yang kosong
df.dropna(subset=['Name'], inplace=True)

# Menampilkan data yang bersih
print('After cleaning:\n')
df
# Out:
# After cleaning:
# /tmp/ipykernel_2448/2780090855.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# /tmp/ipykernel_2448/2780090855.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(), inplace=True)
#       Name    Age   Salary
# 0    Alice  24.00  48000.0
# 1      Bob  30.00  57000.0
# 2  Charlie  27.75  57000.0
# 3    David  22.00  57000.0

# %% [markdown]
# ## Exercise 2: Standardizing Categorical Data

# %%
# Menyiapkan contoh dataset yang memiliki kesalahan pada nama kategorinya yaitu hurufnya tidak Kapital
data = {
    'Product': ['Laptop', 'Laptop', 'Desktop', 'Tablet', 'Tablet'],
    'Category': ['Electronics', 'electronics', 'Electronics', 'Gadgets', 'gadgets']
}
# Menjadikan dataset tersebut menjadi dataframe pandas
df = pd.DataFrame(data)

# Melakukan standarisasi data kategori dengan mengubahnya huruf awalnya menjadi kapital
df['Category'] = df['Category'].str.capitalize()

# Menampilkan contoh data setelah di standarisasi
print('Standardized Data:\n')
df
# Out:
# Standardized Data:
#    Product     Category
# 0   Laptop  Electronics
# 1   Laptop  Electronics
# 2  Desktop  Electronics
# 3   Tablet      Gadgets
# 4   Tablet      Gadgets

# %% [markdown]
# # Practice Tasks
# - Load a dataset of your choice and identify missing values.
# - Implement data transformations to normalize numerical columns.
# - Standardize categorical columns and remove duplicates.

# %% [markdown]
# ## Baca dataset tersebut

# %%
df = pd.read_csv("./archive (2)/tested.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# ## Menhapus setiap nama alias yang dimiliki penumpang

# %%
# MEnghapus setiap nama alias karena sepertinya itu tidak diperlukan
df['Name'] = df['Name'].str.split(pat=',').str[1]

# %% [markdown]
# ## Lihat apakah ada duplikasi pada data kategori

# %%
# Lihat apakah ada duplikasi pada nama
print(df[df['Name'].duplicated() != False])
# Lihat apakah ada duplikasi pada PassengerId
print(df[df['PassengerId'].duplicated() != False])

# Menghapus data yang duplicate tapi tetap mempertahankan data yang pertama
df.drop_duplicates(subset=['Name'], keep='first', inplace=True)
# Out:
#      PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 51           943         0       2             Mr. Franz    male  27.0      0
# 106          998         0       3            Mr. Daniel    male  21.0      0
# 121         1013         0       3              Mr. John    male   NaN      1
# 124         1016         0       3              Mr. John    male   NaN      0
# 145         1037         0       3            Mr. Julius    male  31.0      3
# 148         1040         0       1      Mr. John Bertram    male   NaN      0
# 160         1052         1       3           Miss. Julia  female   NaN      0
# 183         1075         0       3           Mr. Patrick    male   NaN      0
# 187         1079         0       3            Mr. Joseph    male  17.0      2
# 189         1081         0       2             Mr. James    male  40.0      0
# 193         1085         0       2              Mr. John    male  61.0      0
# 206         1098         1       3       Miss. Katherine  female  35.0      0
# 216         1108         1       3   Miss. Bridget Delia  female   NaN      0
# 253         1145         0       3        Mr. Karl Johan    male  24.0      0
# 256         1148         0       3              Mr. John    male   NaN      0
# 270         1162         0       1    Mr. Thomas Francis    male  46.0      0
# 271         1163         0       3           Mr. Patrick    male   NaN      0
# 278         1170         0       2        Mr. John James    male  30.0      1
# 285         1177         0       3           Mr. William    male  36.0      0
# 312         1204         0       3             Mr. Harry    male   NaN      0
# 315         1207         1       3            Miss. Kate  female  17.0      0
# 337         1229         0       3            Mr. Joseph    male  39.0      0
# 352         1244         0       2           Mr. William    male  18.0      0
# 353         1245         0       2            Mr. Samuel    male  49.0      1
# 357         1249         0       3            Mr. Edward    male   NaN      0
# 358         1250         0       3           Mr. Patrick    male   NaN      0
# 363         1255         0       3              Mr. Ivan    male  27.0      0
# 366         1258         0       3            Mr. Joseph    male   NaN      1
# 380         1272         0       3           Mr. Patrick    male   NaN      0
# 381         1273         0       3            Mr. Joseph    male  26.0      0
# 385         1277         1       2            Miss. Kate  female  24.0      1
# 387         1279         0       2              Mr. John    male  57.0      0
# 388         1280         0       3           Mr. Patrick    male  21.0      0
# 393         1285         0       2           Mr. William    male  47.0      0
# 396         1288         0       3           Mr. Patrick    male  24.0      0
# 399         1291         0       3      Mr. Thomas Henry    male  31.0      0
# 401         1293         0       2             Mr. Harry    male  38.0      1
#
#      Parch         Ticket     Fare Cabin Embarked
# 51       0  SC/PARIS 2168  15.0333   NaN        C
# 106      0         330920   7.8208   NaN        Q
# 121      0         367227   7.7500   NaN        Q
# 124      0         368783   7.7500   NaN        Q
# 145      0         345763  18.0000   NaN        S
# 148      0         113791  26.5500   NaN        S
# 160      0         335432   7.7333   NaN        Q
# 183      0           7935   7.7500   NaN        Q
# 187      0      A/4 48873   8.0500   NaN        S
# 189      0          28221  13.0000   NaN        S
# 193      0         235509  12.3500   NaN        Q
# 206      0           9232   7.7500   NaN        Q
# 216      0         330924   7.8792   NaN        Q
# 253      0           7266   9.3250   NaN        S
# 256      0      AQ/4 3130   7.7500   NaN        Q
# 270      0          13050  75.2417    C6        C
# 271      0         368573   7.7500   NaN        Q
# 278      0       CA 31352  21.0000   NaN        S
# 285      0      A/5 21175   7.2500   NaN        S
# 312      0        LP 1588   7.5750   NaN        S
# 315      0    AQ/3. 30631   7.7333   NaN        Q
# 337      2           2675   7.2292   NaN        C
# 352      0   S.O.C. 14879  73.5000   NaN        S
# 353      2         220845  65.0000   NaN        S
# 357      0           1222   7.8792   NaN        S
# 358      0         368402   7.7500   NaN        Q
# 363      0         315083   8.6625   NaN        S
# 366      0           2689  14.4583   NaN        C
# 380      0         366713   7.7500   NaN        Q
# 381      0         330910   7.8792   NaN        Q
# 385      2         220845  65.0000   NaN        S
# 387      0         244346  13.0000   NaN        S
# 388      0         364858   7.7500   NaN        Q
# 393      0     C.A. 30769  10.5000   NaN        S
# 396      0         371109   7.2500   NaN        Q
# 399      0          21332   7.7333   NaN        Q
# 401      0          28664  21.0000   NaN        S
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ## Normalisasi pada data numerical

# %%
# Mengisi data yang kosong pada umur dengan menghitung rata - rata umur
df['Age'].fillna(value=df['Age'].mean(), inplace=True)

# Setelah itu mengubah tipe data umur menjadi int
df['Age'] = df['Age'].astype(int)
# Out:
# /tmp/ipykernel_2448/1013711034.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(value=df['Age'].mean(), inplace=True)

# %% [markdown]
# ## Menghapus beberapa baris dan beberapa kolom

# %%
# Karena pada 
df[df['Fare'].isnull()]
# Out:
#      PassengerId  Survived  Pclass         Name   Sex  Age  SibSp  Parch  \
# 152         1044         0       3   Mr. Thomas  male   60      0      0
#
#     Ticket  Fare Cabin Embarked
# 152   3701   NaN   NaN        S

# %%
# Karena hanya 1 baris saja yang kosong pada Fare maka untuk mempermudah hanya menghapus baris tersebut
df.dropna(subset=['Fare'], inplace=True)
# Menhapus kolom cabin karena datanya banyak yang kosong jadi sudah tidak layak pakai
df.drop(columns=['Cabin'], inplace=True)

# %%
## Menampilkan Dataset yang sudah dibersihkan
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 380 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  380 non-null    int64
#  1   Survived     380 non-null    int64
#  2   Pclass       380 non-null    int64
#  3   Name         380 non-null    object
#  4   Sex          380 non-null    object
#  5   Age          380 non-null    int64
#  6   SibSp        380 non-null    int64
#  7   Parch        380 non-null    int64
#  8   Ticket       380 non-null    object
#  9   Fare         380 non-null    float64
#  10  Embarked     380 non-null    object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 35.6+ KB
#      PassengerId  Survived  Pclass                                 Name  \
# 0            892         0       3                            Mr. James
# 1            893         1       3             Mrs. James (Ellen Needs)
# 2            894         0       2                   Mr. Thomas Francis
# 3            895         0       3                           Mr. Albert
# 4            896         1       3   Mrs. Alexander (Helga E Lindqvist)
# ..           ...       ...     ...                                  ...
# 413         1305         0       3                            Mr. Woolf
# 414         1306         1       1                        Dona. Fermina
# 415         1307         0       3                  Mr. Simon Sivertsen
# 416         1308         0       3                        Mr. Frederick
# 417         1309         0       3                    Master. Michael J
#
#         Sex  Age  SibSp  Parch              Ticket      Fare Embarked
# 0      male   34      0      0              330911    7.8292        Q
# 1    female   47      1      0              363272    7.0000        S
# 2      male   62      0      0              240276    9.6875        Q
# 3      male   27      0      0              315154    8.6625        S
# 4    female   22      1      1             3101298   12.2875        S
# ..      ...  ...    ...    ...                 ...       ...      ...
# 413    male   30      0      0           A.5. 3236    8.0500        S
# 414  female   39      0      0            PC 17758  108.9000        C
# 415    male   38      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male   30      0      0              359309    8.0500        S
# 417    male   30      1      1                2668   22.3583        C
#
# [380 rows x 11 columns]

# %% [markdown]
# # Homework for Students
# - **Pertemuan 12**: Clean a real-world dataset (from Kaggle or another source), perform normalization, handle outliers, and prepare the data for analysis.

# %% [markdown]
# ## Inisiasi dataset
# - Dataframe 1 = https://www.kaggle.com/datasets/sadkoktaybicici/mobile-legends-bang-bang-mlbb-heros-dataset
# - Dataframe 2 = https://www.opendatabay.com/data/ai-ml/9c27ee82-a4db-4260-a82f-8a980ed3f280

# %%
# Import Dataset
df1 = pd.read_csv('./DatasetMLBB/mlbb_heroes.csv').rename(columns={"hero_name":"Name"})
df2 = pd.read_csv('./DatasetMLBB/Mlbb_Heroes.csv')
print(df1.info())
print(df2.info())

# Melakukan join pada untuk kedua dataset
df = pd.merge(df1, df2, how="inner", on="Name")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  103 non-null    object
#  1   role                  103 non-null    object
#  2   defense_overall       103 non-null    float64
#  3   offense_overall       103 non-null    float64
#  4   skill_effect_overall  103 non-null    float64
#  5   difficulty_overall    103 non-null    float64
#  6   movement_spd          103 non-null    int64
#  7   magic_defense         103 non-null    int64
#  8   mana                  103 non-null    int64
#  9   hp_regen              103 non-null    int64
#  10  physical_atk          103 non-null    int64
#  11  physical_defense      103 non-null    int64
#  12  hp                    103 non-null    int64
#  13  attack_speed          103 non-null    float64
#  14  mana_regen            103 non-null    float64
#  15  win_rate              103 non-null    float64
#  16  pick_rate             103 non-null    float64
#  17  ban_rate              103 non-null    float64
#  18  release_year          103 non-null    int64
# dtypes: float64(9), int64(8), object(2)
# memory usage: 15.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            114 non-null    object
#  1   Title           114 non-null    object
#  2   Voice_Line      114 non-null    object
#  3   Release_Date    114 non-null    object
#  4   Primary_Role    114 non-null    object
#  5   Secondary_Role  30 non-null     object
#  6   Lane            114 non-null    object
#  7   Hp              114 non-null    int64
#  8   Hp_Regen        114 non-null    float64
#  9   Mana            114 non-null    int64
#  10  Mana_Regen      113 non-null    float64
#  11  Phy_Damage      114 non-null    int64
#  12  Mag_Damage      114 non-null    int64
#  13  Phy_Defence     114 non-null    int64
#  14  Mag_Defence     114 non-null    int64
#  15  Mov_Speed       114 non-null    int64
#  16  Esport_Wins     114 non-null    int64
#  17  Esport_Loss     114 non-null    int64
# dtypes: float64(2), int64(9), object(7)
# memory usage: 16.2+ KB
# None

# %%
# Melihat info dari dataset yang nantinya akan digunakan
print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  94 non-null     object
#  1   role                  94 non-null     object
#  2   defense_overall       94 non-null     float64
#  3   offense_overall       94 non-null     float64
#  4   skill_effect_overall  94 non-null     float64
#  5   difficulty_overall    94 non-null     float64
#  6   movement_spd          94 non-null     int64
#  7   magic_defense         94 non-null     int64
#  8   mana                  94 non-null     int64
#  9   hp_regen              94 non-null     int64
#  10  physical_atk          94 non-null     int64
#  11  physical_defense      94 non-null     int64
#  12  hp                    94 non-null     int64
#  13  attack_speed          94 non-null     float64
#  14  mana_regen            94 non-null     float64
#  15  win_rate              94 non-null     float64
#  16  pick_rate             94 non-null     float64
#  17  ban_rate              94 non-null     float64
#  18  release_year          94 non-null     int64
#  19  Title                 94 non-null     object
#  20  Voice_Line            94 non-null     object
#  21  Release_Date          94 non-null     object
#  22  Primary_Role          94 non-null     object
#  23  Secondary_Role        25 non-null     object
#  24  Lane                  94 non-null     object
#  25  Hp                    94 non-null     int64
#  26  Hp_Regen              94 non-null     float64
#  27  Mana                  94 non-null     int64
#  28  Mana_Regen            94 non-null     float64
#  29  Phy_Damage            94 non-null     int64
#  30  Mag_Damage            94 non-null     int64
#  31  Phy_Defence           94 non-null     int64
#  32  Mag_Defence           94 non-null     int64
#  33  Mov_Speed             94 non-null     int64
#  34  Esport_Wins           94 non-null     int64
#  35  Esport_Loss           94 non-null     int64
# dtypes: float64(11), int64(17), object(8)
# memory usage: 26.6+ KB
# None
#          Name      role  defense_overall  offense_overall  \
# 0     Terizla   fighter              7.0              8.0
# 1      Martis   fighter              6.0              8.0
# 2       Grock      tank              8.0              5.0
# 3    Carmilla   support              5.0              5.0
# 4     Irithel  marksman              5.0              5.0
# ..        ...       ...              ...              ...
# 89  Esmeralda      mage              7.0              6.0
# 90  Benedetta  assassin              5.0              6.0
# 91      Brody  marksman              6.0              9.0
# 92    Natalia  assassin              6.0              9.0
# 93   Silvanna   fighter              6.0              6.0
#
#     skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 0                    6.0                 6.0           255             10
# 1                    5.0                 5.0           260             10
# 2                    6.0                 4.0           260             10
# 3                    9.0                 5.0           255             10
# 4                    8.0                 7.0           260             10
# ..                   ...                 ...           ...            ...
# 89                   6.0                 4.0           240             10
# 90                   7.0                 7.0           260             10
# 91                   4.0                 7.0           253             10
# 92                   4.0                 6.0           250             10
# 93                   5.0                 4.0           255             10
#
#     mana  hp_regen  ...  Hp_Regen  Mana  Mana_Regen  Phy_Damage  Mag_Damage  \
# 0    430        54  ...      10.8   430        21.0         129           0
# 1      0        35  ...       7.0     0         0.0         128           0
# 2    430        42  ...       8.4   430        12.0         135           0
# 3    430        39  ...       7.8   430        16.0         126           0
# 4    438        35  ...       7.0     0         0.0         118           0
# ..   ...       ...  ...       ...   ...         ...         ...         ...
# 89   502        36  ...       7.2   502        20.0         114           0
# 90   460        33  ...       6.6   460        16.0         113           0
# 91   435        36  ...       7.2   435        15.0         105           0
# 92   486        35  ...       7.0   486        16.0         121           0
# 93   430        39  ...       7.8   430        16.0         126           0
#
#     Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins Esport_Loss
# 0            19           15        255          103         105
# 1            25           15        260           95         110
# 2            21           15        260          601         634
# 3            25           15        255           32          47
# 4            17           15        260          114         109
# ..          ...          ...        ...          ...         ...
# 89           21           15        240         1357        1529
# 90           18           15        255          477         471
# 91           20           15        253          470         476
# 92           18           15        260          173         173
# 93           22           15        255           88          84
#
# [94 rows x 36 columns]

# %% [markdown]
# ## Menghapus beberapa kolom yang menampilkan informasi yang sama

# %%
df.drop(columns=['role', 'defense_overall', 'offense_overall','movement_spd',
       'magic_defense', 'mana', 'hp_regen', 'physical_atk', 'physical_defense',
       'hp', 'mana_regen'], inplace=True)
df
# Out:
#          Name  skill_effect_overall  difficulty_overall  attack_speed  \
# 0     Terizla                   6.0                 6.0          0.80
# 1      Martis                   5.0                 5.0          0.86
# 2       Grock                   6.0                 4.0          0.81
# 3    Carmilla                   9.0                 5.0          0.91
# 4     Irithel                   8.0                 7.0          0.82
# ..        ...                   ...                 ...           ...
# 89  Esmeralda                   6.0                 4.0          0.80
# 90  Benedetta                   7.0                 7.0          0.88
# 91      Brody                   4.0                 7.0          0.96
# 92    Natalia                   4.0                 6.0          0.89
# 93   Silvanna                   5.0                 4.0          0.91
#
#     win_rate  pick_rate  ban_rate  release_year               Title  \
# 0      47.00       0.15      0.02          2019         Executioner
# 1      45.00       0.15      0.02          2018         Ashura King
# 2      47.69       0.14      0.02          2017      Fortress Titan
# 3      53.76       0.08      0.02          2020  Shadow of Twilight
# 4      51.52       0.38      0.03          2017        Jungle Heart
# ..       ...        ...       ...           ...                 ...
# 89     49.14       1.25     42.29          2019          Astrologer
# 90     52.38       0.72     49.46          2020       Shadow Ranger
# 91     51.57       0.71     60.05          2020       The Lone Star
# 92     47.76       0.41     61.29          2016         Bright Claw
# 93     52.65       3.06      9.59          2019  Imperial Knightess
#
#                                    Voice_Line  ... Hp_Regen Mana Mana_Regen  \
# 0                                Primary Role  ...     10.8  430       21.0
# 1                                Primary Role  ...      7.0    0        0.0
# 2                                Primary Role  ...      8.4  430       12.0
# 3                     True love is like blood  ...      7.8  430       16.0
# 4                                Primary Role  ...      7.0    0        0.0
# ..                                        ...  ...      ...  ...        ...
# 89                             Secondary Role  ...      7.2  502       20.0
# 90  When the body suffers, the spirit blooms.  ...      6.6  460       16.0
# 91     Pain is the proof the I'm still alive.  ...      7.2  435       15.0
# 92                               Primary Role  ...      7.0  486       16.0
# 93                               Primary Role  ...      7.8  430       16.0
#
#    Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0         129           0           19           15        255          103
# 1         128           0           25           15        260           95
# 2         135           0           21           15        260          601
# 3         126           0           25           15        255           32
# 4         118           0           17           15        260          114
# ..        ...         ...          ...          ...        ...          ...
# 89        114           0           21           15        240         1357
# 90        113           0           18           15        255          477
# 91        105           0           20           15        253          470
# 92        121           0           18           15        260          173
# 93        126           0           22           15        255           88
#
#     Esport_Loss
# 0           105
# 1           110
# 2           634
# 3            47
# 4           109
# ..          ...
# 89         1529
# 90          471
# 91          476
# 92          173
# 93           84
#
# [94 rows x 25 columns]

# %% [markdown]
# ## Menghapus beberapa kolom yang tidak relevan untuk analisis dan tidak relevan dari kedua data yang digabungkan

# %%
df.drop(columns=['win_rate', 'pick_rate', 'ban_rate', 'release_year', 'Secondary_Role', 'Title',
       'Voice_Line'], inplace=True)
df
# Out:
#          Name  skill_effect_overall  difficulty_overall  attack_speed  \
# 0     Terizla                   6.0                 6.0          0.80
# 1      Martis                   5.0                 5.0          0.86
# 2       Grock                   6.0                 4.0          0.81
# 3    Carmilla                   9.0                 5.0          0.91
# 4     Irithel                   8.0                 7.0          0.82
# ..        ...                   ...                 ...           ...
# 89  Esmeralda                   6.0                 4.0          0.80
# 90  Benedetta                   7.0                 7.0          0.88
# 91      Brody                   4.0                 7.0          0.96
# 92    Natalia                   4.0                 6.0          0.89
# 93   Silvanna                   5.0                 4.0          0.91
#
#    Release_Date Primary_Role       Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0    2019-06-04      Fighter   EXP Lane  2728      10.8   430        21.0
# 1          2018      Fighter   EXP Lane  2738       7.0     0         0.0
# 2          2017         Tank     Roamer  2819       8.4   430        12.0
# 3    2020-01-17      Support     Roamer  2528       7.8   430        16.0
# 4    2017-08-15     Marksman  Gold Lane  2540       7.0     0         0.0
# ..          ...          ...        ...   ...       ...   ...         ...
# 89   2019-04-02         Mage   EXP Lane  2573       7.2   502        20.0
# 90   2020-11-07     Assassin   EXP Lane  2569       6.6   460        16.0
# 91   2020-10-16     Marksman  Gold Lane  2490       7.2   435        15.0
# 92      2016-12     Assassin    Jungler  2639       7.0   486        16.0
# 93   2019-12-17      Fighter   EXP Lane  2868       7.8   430        16.0
#
#     Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0          129           0           19           15        255          103
# 1          128           0           25           15        260           95
# 2          135           0           21           15        260          601
# 3          126           0           25           15        255           32
# 4          118           0           17           15        260          114
# ..         ...         ...          ...          ...        ...          ...
# 89         114           0           21           15        240         1357
# 90         113           0           18           15        255          477
# 91         105           0           20           15        253          470
# 92         121           0           18           15        260          173
# 93         126           0           22           15        255           88
#
#     Esport_Loss
# 0           105
# 1           110
# 2           634
# 3            47
# 4           109
# ..          ...
# 89         1529
# 90          471
# 91          476
# 92          173
# 93           84
#
# [94 rows x 18 columns]

# %% [markdown]
# ## Menambahkan Fitur baru

# %%
# Melihat setiap hero berapa kali digunakan pada perlombaan Esport
df['Total_Match'] = df['Esport_Wins'] + df['Esport_Loss']

# Melihat winrate setiap hero dari setiap match
df['Winrate'] = (df['Esport_Wins'] / df['Total_Match']) * 100
# Bulatkan persentase tersebut
df['Winrate'] = df['Winrate'].round(decimals=1)
df
# Out:
#          Name  skill_effect_overall  difficulty_overall  attack_speed  \
# 0     Terizla                   6.0                 6.0          0.80
# 1      Martis                   5.0                 5.0          0.86
# 2       Grock                   6.0                 4.0          0.81
# 3    Carmilla                   9.0                 5.0          0.91
# 4     Irithel                   8.0                 7.0          0.82
# ..        ...                   ...                 ...           ...
# 89  Esmeralda                   6.0                 4.0          0.80
# 90  Benedetta                   7.0                 7.0          0.88
# 91      Brody                   4.0                 7.0          0.96
# 92    Natalia                   4.0                 6.0          0.89
# 93   Silvanna                   5.0                 4.0          0.91
#
#    Release_Date Primary_Role       Lane    Hp  Hp_Regen  Mana  Mana_Regen  \
# 0    2019-06-04      Fighter   EXP Lane  2728      10.8   430        21.0
# 1          2018      Fighter   EXP Lane  2738       7.0     0         0.0
# 2          2017         Tank     Roamer  2819       8.4   430        12.0
# 3    2020-01-17      Support     Roamer  2528       7.8   430        16.0
# 4    2017-08-15     Marksman  Gold Lane  2540       7.0     0         0.0
# ..          ...          ...        ...   ...       ...   ...         ...
# 89   2019-04-02         Mage   EXP Lane  2573       7.2   502        20.0
# 90   2020-11-07     Assassin   EXP Lane  2569       6.6   460        16.0
# 91   2020-10-16     Marksman  Gold Lane  2490       7.2   435        15.0
# 92      2016-12     Assassin    Jungler  2639       7.0   486        16.0
# 93   2019-12-17      Fighter   EXP Lane  2868       7.8   430        16.0
#
#     Phy_Damage  Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  \
# 0          129           0           19           15        255          103
# 1          128           0           25           15        260           95
# 2          135           0           21           15        260          601
# 3          126           0           25           15        255           32
# 4          118           0           17           15        260          114
# ..         ...         ...          ...          ...        ...          ...
# 89         114           0           21           15        240         1357
# 90         113           0           18           15        255          477
# 91         105           0           20           15        253          470
# 92         121           0           18           15        260          173
# 93         126           0           22           15        255           88
#
#     Esport_Loss  Total_Match  Winrate
# 0           105          208     49.5
# 1           110          205     46.3
# 2           634         1235     48.7
# 3            47           79     40.5
# 4           109          223     51.1
# ..          ...          ...      ...
# 89         1529         2886     47.0
# 90          471          948     50.3
# 91          476          946     49.7
# 92          173          346     50.0
# 93           84          172     51.2
#
# [94 rows x 20 columns]

# %% [markdown]
# ## Mengganti Release_Date dengan Season hero tersebut release

# %%
import math
# Mengubah tipe data release_date menjadi tanggal terlebih dahulu
df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce', format='mixed')


try:
    # Menghitung selisih bulan dari season tersebut
    bulan = (df['Release_Date'].dt.year - 2016) * 12 + (df['Release_Date'].dt.month - 7)

    # Menghitung season
    df['Season'] = bulan // 3 + 1

except:
    df['Season'] = pd.NA

# Saat ditampilkan masih nanyak yang NaN seasonnya oleh sebab itu data yang NaN akan diisi dengan nilai tengah season di tahun tersebut
print(df['Season'])

# Tambahkan kolom tahun
df['Year'] = df['Release_Date'].dt.year
# Hitung nilai tengah season setiap tahun
nilaiTengah = df.groupby('Year')['Season'].median()

# Gunakan DataFrame.map untuk mmengganti kolom yang kosong dengan nilai tengah tahun
df['Season'] = df['Season'].fillna(df['Year'].map(nilaiTengah))

# Menampilkan data yang sudah dibersihkan
df
# Out:
# 0     12
# 1      7
# 2      3
# 3     15
# 4      5
#       ..
# 89    12
# 90    18
# 91    18
# 92     2
# 93    14
# Name: Season, Length: 94, dtype: int32
#          Name  skill_effect_overall  difficulty_overall  attack_speed  \
# 0     Terizla                   6.0                 6.0          0.80
# 1      Martis                   5.0                 5.0          0.86
# 2       Grock                   6.0                 4.0          0.81
# 3    Carmilla                   9.0                 5.0          0.91
# 4     Irithel                   8.0                 7.0          0.82
# ..        ...                   ...                 ...           ...
# 89  Esmeralda                   6.0                 4.0          0.80
# 90  Benedetta                   7.0                 7.0          0.88
# 91      Brody                   4.0                 7.0          0.96
# 92    Natalia                   4.0                 6.0          0.89
# 93   Silvanna                   5.0                 4.0          0.91
#
#    Release_Date Primary_Role       Lane    Hp  Hp_Regen  Mana  ...  \
# 0    2019-06-04      Fighter   EXP Lane  2728      10.8   430  ...
# 1    2018-01-01      Fighter   EXP Lane  2738       7.0     0  ...
# 2    2017-01-01         Tank     Roamer  2819       8.4   430  ...
# 3    2020-01-17      Support     Roamer  2528       7.8   430  ...
# 4    2017-08-15     Marksman  Gold Lane  2540       7.0     0  ...
# ..          ...          ...        ...   ...       ...   ...  ...
# 89   2019-04-02         Mage   EXP Lane  2573       7.2   502  ...
# 90   2020-11-07     Assassin   EXP Lane  2569       6.6   460  ...
# 91   2020-10-16     Marksman  Gold Lane  2490       7.2   435  ...
# 92   2016-12-01     Assassin    Jungler  2639       7.0   486  ...
# 93   2019-12-17      Fighter   EXP Lane  2868       7.8   430  ...
#
#     Mag_Damage  Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  Esport_Loss  \
# 0            0           19           15        255          103          105
# 1            0           25           15        260           95          110
# 2            0           21           15        260          601          634
# 3            0           25           15        255           32           47
# 4            0           17           15        260          114          109
# ..         ...          ...          ...        ...          ...          ...
# 89           0           21           15        240         1357         1529
# 90           0           18           15        255          477          471
# 91           0           20           15        253          470          476
# 92           0           18           15        260          173          173
# 93           0           22           15        255           88           84
#
#     Total_Match  Winrate  Season  Year
# 0           208     49.5      12  2019
# 1           205     46.3       7  2018
# 2          1235     48.7       3  2017
# 3            79     40.5      15  2020
# 4           223     51.1       5  2017
# ..          ...      ...     ...   ...
# 89         2886     47.0      12  2019
# 90          948     50.3      18  2020
# 91          946     49.7      18  2020
# 92          346     50.0       2  2016
# 93          172     51.2      14  2019
#
# [94 rows x 22 columns]

# %% [markdown]
# ## Menyempurnakan dan membuang kolom yang tadi digunakan untuk membantu perhitungan

# %%
df.drop(columns=['Release_Date', 'Year', 'Mag_Damage'], inplace=True)

# %%
## Data yang sudah dibersihkan dan siap di analisis
df
# Out:
#          Name  skill_effect_overall  difficulty_overall  attack_speed  \
# 0     Terizla                   6.0                 6.0          0.80
# 1      Martis                   5.0                 5.0          0.86
# 2       Grock                   6.0                 4.0          0.81
# 3    Carmilla                   9.0                 5.0          0.91
# 4     Irithel                   8.0                 7.0          0.82
# ..        ...                   ...                 ...           ...
# 89  Esmeralda                   6.0                 4.0          0.80
# 90  Benedetta                   7.0                 7.0          0.88
# 91      Brody                   4.0                 7.0          0.96
# 92    Natalia                   4.0                 6.0          0.89
# 93   Silvanna                   5.0                 4.0          0.91
#
#    Primary_Role       Lane    Hp  Hp_Regen  Mana  Mana_Regen  Phy_Damage  \
# 0       Fighter   EXP Lane  2728      10.8   430        21.0         129
# 1       Fighter   EXP Lane  2738       7.0     0         0.0         128
# 2          Tank     Roamer  2819       8.4   430        12.0         135
# 3       Support     Roamer  2528       7.8   430        16.0         126
# 4      Marksman  Gold Lane  2540       7.0     0         0.0         118
# ..          ...        ...   ...       ...   ...         ...         ...
# 89         Mage   EXP Lane  2573       7.2   502        20.0         114
# 90     Assassin   EXP Lane  2569       6.6   460        16.0         113
# 91     Marksman  Gold Lane  2490       7.2   435        15.0         105
# 92     Assassin    Jungler  2639       7.0   486        16.0         121
# 93      Fighter   EXP Lane  2868       7.8   430        16.0         126
#
#     Phy_Defence  Mag_Defence  Mov_Speed  Esport_Wins  Esport_Loss  \
# 0            19           15        255          103          105
# 1            25           15        260           95          110
# 2            21           15        260          601          634
# 3            25           15        255           32           47
# 4            17           15        260          114          109
# ..          ...          ...        ...          ...          ...
# 89           21           15        240         1357         1529
# 90           18           15        255          477          471
# 91           20           15        253          470          476
# 92           18           15        260          173          173
# 93           22           15        255           88           84
#
#     Total_Match  Winrate  Season
# 0           208     49.5      12
# 1           205     46.3       7
# 2          1235     48.7       3
# 3            79     40.5      15
# 4           223     51.1       5
# ..          ...      ...     ...
# 89         2886     47.0      12
# 90          948     50.3      18
# 91          946     49.7      18
# 92          346     50.0       2
# 93          172     51.2      14
#
# [94 rows x 19 columns]
